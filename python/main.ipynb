# %% [markdown]
# # Spatial distribution of L5 cells in M1/M2

# %% [markdown]
# ## List data files

# %%
import os
import openpyxl as px
import numpy as np
import matplotlib.pyplot as plt
from sklearn import decomposition as deco
from matplotlib.mlab import PCA as mlabPCA
import scipy
from scipy.spatial import ConvexHull
import math
from tabulate import tabulate
import xlsxwriter
import scipy.stats.stats as st


path_data=r'data/'    
path_images='images/'
log_filename ="input/10x_depth-log_blank.xlsx"
z_resolution = 2.89 #um thickness of the 3D slice

def list_files(path):
    # returns a list of names (with extension, without full path) of all files 
    # in folder path
    files = []
    for name in os.listdir(path):
        if os.path.isfile(os.path.join(path, name)):
            files.append(name)
    return files

def get_xydata(ws):
    # returns xy data 2D array from the work sheet ws
    last_row = ws.get_highest_row() + 1
    sheetdata = []
    for row in range(2,last_row):
            for col in ["A","B"]:
                cellname=col+str(row)
                if ws[cellname].value:
                    sheetdata.append(ws[cellname].value)

    xydata = np.reshape(sheetdata, (len(sheetdata)/2, 2))
    xydata.shape
    return xydata

def areatype(sheet):
    # define area type from the text in the sheet name
    if "m1" in sheet:
        return "M1"
    elif "M1" in sheet:
        return "M1"
    else:
        return "M2"

def genotype(file):
    # define genotype from the text in the file name
    if "CKO" in file:
        return "CKO"
    elif "WT" in file:
        return "WT"
    else:
        return "NA"    
    
def plot_pcadata(path_images,cadata,hull,file,sheet):
    # plot pcadata and hull around
    fig = plt.figure()
    ay = fig.add_subplot(1, 1, 1)
    if "M1" in areatype(sheet):
        ay.scatter(pcadata[:,0], pcadata[:,1], color="blue")
    else:
        ay.scatter(pcadata[:,0], pcadata[:,1], color="red")

 

    for simplex in hull.simplices:
        plt.plot(pcadata[simplex, 0], pcadata[simplex, 1], 'k-')
    plt.grid()
    plt.axis('equal')
    plt.title(file+"   ["+sheet+"]", fontsize=10)


    plt.axis([-1000, 1000, -1000, 1000])
    plt.savefig(path_images+file+'_'+sheet+'.png', bbox_inches='tight')
    
def file_log(log_filename, path_data):
    # write preliminary file log in file
    workbook_depth = xlsxwriter.Workbook(log_filename)
    worksheet_depth = workbook_depth.add_worksheet()


    row = 0
    col = 0

    # executing the main script
    files = list_files(path_data)

    for file in files:
        worksheet_depth.write(0 + row, 0, file)
        row = row +1

    workbook_depth.close()

# %% [markdown]
# ## Create a file log

# %%
# this is just to create the log of all files and then to use it to populate 
file_log(log_filename, path_data)

# %%
wb_depth = px.load_workbook("input/10x_depth-log.xlsx")
ws_depth = wb_depth["Sheet1"]

last_row_depth = ws_depth.get_highest_row() + 1
logdata = []

for row in range(2,last_row_depth):
        for col in ["A","B","C"]:
            cellname=col+str(row)
            logdata.append(ws_depth[cellname].value)
alllog = np.reshape(logdata, (len(logdata)/3, 3))
print(alllog)
# Out:
# [['10x position_EMXCKO1-slice-3.xlsx' '24' '16']
#  ['10x position_EMXCKO1-slice-5.xlsx' '23' '23']
#  ['10x position_EMXCKO2-slice-3.xlsx' '26' '15']
#  ['10x position_EMXCKO2-slice-4.xlsx' '29' '19']
#  ['10x position_EMXCKO2-slice-5.xlsx' '24' '23']
#  ['10x position_EMXCKO3-slice-3-stitch2.xlsx' '24' '16']
#  ['10x position_EMXCKO3-slice-4.xlsx' '26' '25']
#  ['10x position_EMXCKO4-column-1-slice-7.xlsx' '18' '16']
#  ['10x position_EMXCKO4-column-1-slice-8.xlsx' '15' '16']
#  ['10x position_EMXCKO4-column-2-slice-7-stitch2.xlsx' '17' '16']
#  ['10x position_EMXCKO4-column-2-slice-8.xlsx' '24' '16']
#  ['10x position_EMXCKO5-column-1-slice-3.xlsx' '18' '23']
#  ['10x position_EMXCKO5-column-2-slice-1.xlsx' '20' '17']
#  ['10x position_EMXCKO5-column-2-slice-2.xlsx' '22' '16']
#  ['10x position_EMXCKO5-column-2-slice-3.xlsx' '26' '25']
#  ['10x position_WT1-N5-column-1-slice-1.xlsx' '29' '16']
#  ['10x position_WT1-N5-column-2-slice-1.xlsx' '25' '15']
#  ['10x position_WT1-N5-column-2-slice-2.xlsx' '40' '22']
#  ['10x position_WT1-N5-column-2-slice-3.xlsx' '39' '22']
#  ['10x position_WT2-N3-column-2-slice-1.xlsx' '34' '22']
#  ['10x position_WT2-N3-column-2-slice-2.xlsx' '29' '21']
#  ['10x position_WT3-N3-column-1-slice-1.xlsx' '35' '18']
#  ['10x position_WT3-N3-column-2-slice-1.xlsx' '37' '21']
#  ['10x position_WT3-N3-column-2-slice-2.xlsx' '40' '26']
#  ['10x position_WT4-N5-column-2-slice-1.xlsx' '29' '18']
#  ['10x position_WT5-N3-column-2-slice-1.xlsx' '33' '18']
#  ['10x position_WT5-N3-column-2-slice-2.xlsx' '45' '22']
#  ['10x position_WT5-N3-column-2-slice-3.xlsx' '33' '22']
#  ['10x position_WT6-N5-column-2-slice-1.xlsx' '32' '23']]

# %% [markdown]
# ## Open selected sheet

# %%
# preparing the file for the results to be written to
analysisdata = []
analysisdata.append( ["Filename", "Area", "Neurons", "Density", "H", "L", "SD_H", "SD_L", "Genotype"] )

workbook = xlsxwriter.Workbook('results/10x_results.xlsx')
worksheet = workbook.add_worksheet()

for roww in range(0,len(analysisdata[0])):
    worksheet.write(0, 0 + roww, analysisdata[0][roww])

row = 1
col = 0

# executing the main script
files = list_files(path_data)
fileno = 0

for file in files:
    wb = px.load_workbook(path_data+file)
    print("")
    print("=================================================")
    print(file)
    sheets = wb.get_sheet_names()
 
    z_depth=alllog[fileno][1]
    print(z_depth)


    for sheet in sheets:
        # listing the sheets in the doc
        print(sheet)
        ws = wb[sheet]
        # extract data from the sheet
        xydata = get_xydata(ws)
        
        # perform PCA
        pca = deco.PCA(2) # n_components is the components number after reduction
        pcadata = pca.fit(xydata).transform(xydata)

        # LH is dimetion array keeping ranges of the area covered by cells
        LH = np.ptp(pcadata, axis=0)
        print("NEURONS: "+str(xydata.shape[0]))
        print("LENGTH: "+str(LH[0]))
        print("HEIGHT: "+str(LH[1]))
        # Calculate ConvexHull
        hull = ConvexHull(pcadata, qhull_options="FA")
        #print(hull)
        SD_H = np.std(pcadata[0])
        SD_L = np.std(pcadata[1])
        
        print("SD_H: "+str(SD_H))
        print("SD_L: "+str(SD_L))
        print ("H_skewness:", st.skew(pcadata[0], bias=False))
    
        
        densityvolume = SD_L*SD_H*math.pi*int(z_resolution)*int(z_depth)
        
        #density calculation
        print("DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: "+str(xydata.shape[0]/(densityvolume)))
        analysisdata.append( [file[13:], areatype(sheet), xydata.shape[0], xydata.shape[0]/(densityvolume), LH[0], LH[1], SD_H, SD_L, genotype(file)] )

        print("")
        plot_pcadata(path_images,pcadata,hull,file,sheet)
        
        worksheet.write(row, col + 0, file[13:])
        worksheet.write(row, col + 1, areatype(sheet))
        worksheet.write(row, col + 2, xydata.shape[0])
        worksheet.write(row, col + 3, xydata.shape[0]/(densityvolume))
        worksheet.write(row, col + 4, LH[0])
        worksheet.write(row, col + 5, LH[1])
        worksheet.write(row, col + 6, SD_H)
        worksheet.write(row, col + 7, SD_L)
        worksheet.write(row, col + 8, genotype(file))
        
        row += 1
    
    
    fileno=fileno+1
    print("")

print(tabulate(analysisdata, tablefmt="fancy_grid",headers="firstrow"))
workbook.close()
# Out:
# =================================================
# 10x position_EMXCKO1-slice-3.xlsx
# 24
# 1-M1
# NEURONS: 192
# LENGTH: 1270.75128879
# HEIGHT: 514.57825698
# SD_H: 339.930281575
# SD_L: 197.545094335
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.89606846578e-05
#
# 1-M2
# NEURONS: 62
# LENGTH: 858.12890116
# HEIGHT: 770.249828369
# SD_H: 50.0471798046
# SD_L: 134.351641523
# H_skewness: 8.126047694861378e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 6.11473996064e-05
#
# 2-M1
# NEURONS: 196
# LENGTH: 1350.13621237
# HEIGHT: 557.789068854
# SD_H: 441.881793028
# SD_L: 128.03547404
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.29735727457e-05
#
# 2-M2
# NEURONS: 48
# LENGTH: 760.261830496
# HEIGHT: 644.799444471
# SD_H: 223.091311193
# SD_L: 19.769848624
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.21712333848e-05
#
#
#
# =================================================
# 10x position_EMXCKO1-slice-5.xlsx
# 23
# 1-m1
# NEURONS: 122
# LENGTH: 1301.18957527
# HEIGHT: 433.951601712
# SD_H: 157.905131405
# SD_L: 185.873654495
# H_skewness: -5.322233423353847e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.87632559016e-05
#
# 1-m2
# NEURONS: 34
# LENGTH: 669.512530327
# HEIGHT: 340.89295833
# SD_H: 130.858201956
# SD_L: 143.80966393
# H_skewness: 3.117156073505376e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.25020776702e-05
#
# 2-m1
# NEURONS: 96
# LENGTH: 1342.22158691
# HEIGHT: 369.99765412
# SD_H: 358.119773658
# SD_L: 100.635443797
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.84325007896e-05
#
# 2-m2
# NEURONS: 39
# LENGTH: 916.128407841
# HEIGHT: 634.603878068
# SD_H: 192.811905515
# SD_L: 134.869551866
# H_skewness: -4.547436406379064e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.03778918736e-05
#
#
#
# =================================================
# 10x position_EMXCKO2-slice-3.xlsx
# 26
# 1-M1
# NEURONS: 159
# LENGTH: 1053.47796685
# HEIGHT: 493.59454579
# SD_H: 214.174817137
# SD_L: 102.669772583
# H_skewness: -1.8959414063436283e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 4.42621905173e-05
#
# 1-M2
# C:\Users\Nikita\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# C:\Users\Nikita\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# NEURONS: 52
# LENGTH: 1006.19622771
# HEIGHT: 777.367253361
# SD_H: 223.811140888
# SD_L: 9.14776504597
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000155472443662
#
# 2-M1
# NEURONS: 140
# LENGTH: 925.371382074
# HEIGHT: 444.344063661
# SD_H: 287.754681424
# SD_L: 109.942383848
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.70886443998e-05
#
# 2-M2
# NEURONS: 79
# LENGTH: 1012.03117956
# HEIGHT: 912.065264146
# SD_H: 306.956734539
# SD_L: 40.8170815886
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.85971074836e-05
#
#
#
# =================================================
# 10x position_EMXCKO2-slice-4.xlsx
# 29
# 1-m1
# NEURONS: 148
# LENGTH: 1399.52184686
# HEIGHT: 382.738802894
# SD_H: 310.336107831
# SD_L: 176.76965229
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.48062075348e-05
#
# 1-m2
# NEURONS: 42
# LENGTH: 827.76912482
# HEIGHT: 409.803620679
# SD_H: 200.915836978
# SD_L: 42.9895318694
# H_skewness: 1.1483059559099953e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.6686679341e-05
#
# 2-m1
# NEURONS: 136
# LENGTH: 1409.64621147
# HEIGHT: 407.531198151
# SD_H: 343.485459682
# SD_L: 183.993491896
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.18100088501e-05
#
# 2-m2
# NEURONS: 57
# LENGTH: 508.116414663
# HEIGHT: 503.741145715
# SD_H: 220.470195405
# SD_L: 76.6686308296
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.85067174658e-05
#
#
#
# =================================================
# 10x position_EMXCKO2-slice-5.xlsx
# 24
# 1-m1
# NEURONS: 89
# LENGTH: 1370.00237384
# HEIGHT: 425.267183692
# SD_H: 355.72808884
# SD_L: 75.5527241871
# H_skewness: -2.4827151752896245e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.19599126991e-05
#
# 1-m2
# NEURONS: 29
# LENGTH: 758.347968772
# HEIGHT: 440.51066267
# SD_H: 163.191734967
# SD_L: 192.802261259
# H_skewness: -5.357296213326661e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 6.11218660856e-06
#
# 2-m1
# NEURONS: 106
# LENGTH: 1357.47107242
# HEIGHT: 364.024268117
# SD_H: 290.944934441
# SD_L: 70.6709517809
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.41871592214e-05
#
# 2-m2
# NEURONS: 33
# LENGTH: 832.478374491
# HEIGHT: 447.17222304
# SD_H: 265.458411273
# SD_L: 16.9999307429
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 4.84930150121e-05
#
#
#
# =================================================
# 10x position_EMXCKO3-slice-3-stitch2.xlsx
# 24
# 1-m1
# NEURONS: 151
# LENGTH: 1443.83032081
# HEIGHT: 557.621240711
# SD_H: 427.558997287
# SD_L: 230.094721035
# H_skewness: 2.8597180865602853e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.01784847991e-05
#
# 1-m2
# NEURONS: 19
# LENGTH: 654.848640779
# HEIGHT: 510.236231944
# SD_H: 246.376938058
# SD_L: 190.053204251
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.69083607347e-06
#
# 2-m1
# NEURONS: 151
# LENGTH: 1297.91593976
# HEIGHT: 613.90328003
# SD_H: 337.927246769
# SD_L: 151.215496883
# H_skewness: -2.89608794753916e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.95959501688e-05
#
# 2-m2
# NEURONS: 32
# LENGTH: 746.538857775
# HEIGHT: 625.791890955
# SD_H: 161.209838942
# SD_L: 123.213059856
# H_skewness: 2.22292851975716e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.06834268628e-05
#
#
#
# =================================================
# 10x position_EMXCKO3-slice-4.xlsx
# 26
# 1-m1
# NEURONS: 174
# LENGTH: 1302.19376812
# HEIGHT: 432.880679067
# SD_H: 269.787143808
# SD_L: 149.827285273
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.6350197277e-05
#
# 1-m2
# NEURONS: 38
# LENGTH: 637.534822292
# HEIGHT: 751.626111791
# SD_H: 185.482431587
# SD_L: 109.828379045
# H_skewness: 2.918917254507381e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.14186043668e-05
#
# 2-m1
# NEURONS: 179
# LENGTH: 1261.88499123
# HEIGHT: 483.354491387
# SD_H: 260.238474324
# SD_L: 148.327406943
# H_skewness: -4.2274220129239204e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.83861769707e-05
#
# 2-m2
# NEURONS: 24
# LENGTH: 491.337080751
# HEIGHT: 411.091724071
# SD_H: 258.95561898
# SD_L: 189.083605463
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.00039761422e-06
#
#
#
# =================================================
# 10x position_EMXCKO4-column-1-slice-7.xlsx
# 18
# 1-M2
# NEURONS: 36
# LENGTH: 853.956152501
# HEIGHT: 750.128181554
# SD_H: 358.712235338
# SD_L: 156.182890456
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 5.68159772425e-06
#
# 1-M1
# NEURONS: 133
# LENGTH: 1366.23205957
# HEIGHT: 683.885594572
# SD_H: 481.213050914
# SD_L: 143.082092004
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.70795564841e-05
#
# 2-M1
# NEURONS: 92
# LENGTH: 1503.91409746
# HEIGHT: 566.527733374
# SD_H: 392.913741385
# SD_L: 127.529601952
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.62340631883e-05
#
# 2-M2
# NEURONS: 24
# LENGTH: 782.547588047
# HEIGHT: 524.253850673
# SD_H: 129.374881598
# SD_L: 131.372379563
# H_skewness: -3.2256073308025317e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.24854683046e-05
#
#
#
# =================================================
# 10x position_EMXCKO4-column-1-slice-8.xlsx
# 15
# 1-M2
# NEURONS: 32
# LENGTH: 773.463949066
# HEIGHT: 655.367949316
# SD_H: 169.723265738
# SD_L: 270.03652589
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.40823856309e-06
#
# 1-m1
# NEURONS: 133
# LENGTH: 1434.87515237
# HEIGHT: 444.928730071
# SD_H: 377.785639569
# SD_L: 199.970581649
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.86796596203e-05
#
# 2-M2
# NEURONS: 22
# LENGTH: 685.527596689
# HEIGHT: 529.406979813
# SD_H: 114.725335642
# SD_L: 1.91747078273
# H_skewness: -3.854802540938167e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00106111746166
#
# 2-M1
# NEURONS: 117
# LENGTH: 1463.08280297
# HEIGHT: 683.108021299
# SD_H: 451.799734423
# SD_L: 222.907087621
# H_skewness: -2.423669836378787e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.23266449046e-05
#
#
#
# =================================================
# 10x position_EMXCKO4-column-2-slice-7-stitch2.xlsx
# 17
# 1-m1
# NEURONS: 124
# LENGTH: 1558.46139176
# HEIGHT: 690.159015926
# SD_H: 493.117969975
# SD_L: 189.129231162
# H_skewness: 1.8640556951209657e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.24475365207e-05
#
# 1-m2
# NEURONS: 22
# LENGTH: 747.442670138
# HEIGHT: 501.988253783
# SD_H: 156.662022608
# SD_L: 51.3029977164
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.56263893033e-05
#
# 2-m2
# NEURONS: 34
# LENGTH: 946.804900623
# HEIGHT: 794.00224007
# SD_H: 168.023244423
# SD_L: 27.5138614053
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 6.88540064059e-05
#
# 2-m1
# NEURONS: 93
# LENGTH: 1356.39316137
# HEIGHT: 584.903841462
# SD_H: 296.784558431
# SD_L: 73.3040905984
# H_skewness: -2.8501401357764063e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 4.00206969471e-05
#
#
#
# =================================================
# 10x position_EMXCKO4-column-2-slice-8.xlsx
# 24
# 1-m2
# NEURONS: 35
# LENGTH: 798.226609521
# HEIGHT: 717.90697991
# SD_H: 200.384514221
# SD_L: 102.111115015
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.13433089193e-05
#
# 1-m1
# NEURONS: 107
# LENGTH: 1513.06627588
# HEIGHT: 613.02424755
# SD_H: 405.236219499
# SD_L: 67.0507932729
# H_skewness: -1.1196063468374306e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.61144264676e-05
#
#
#
# =================================================
# 10x position_EMXCKO5-column-1-slice-3.xlsx
# 18
# 1-m1
# NEURONS: 97
# LENGTH: 1245.25188267
# HEIGHT: 508.215856357
# SD_H: 388.910980434
# SD_L: 108.115765857
# H_skewness: 1.2666000527072096e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.03976495828e-05
#
# 1-m2
# NEURONS: 16
# LENGTH: 637.760098424
# HEIGHT: 623.66246622
# SD_H: 2.47922212858
# SD_L: 29.9312967445
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00190645534385
#
# 2-m1
# NEURONS: 81
# LENGTH: 1297.23901322
# HEIGHT: 446.390845189
# SD_H: 394.182032367
# SD_L: 127.333550488
# H_skewness: 1.8246976094153877e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.42689814126e-05
#
# 2-m2
# NEURONS: 12
# LENGTH: 623.234104767
# HEIGHT: 558.034636449
# SD_H: 38.1856350359
# SD_L: 236.589522738
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.17444679478e-05
#
#
#
# =================================================
# 10x position_EMXCKO5-column-2-slice-1.xlsx
# 20
# 1-m1
# NEURONS: 115
# LENGTH: 1537.3440059
# HEIGHT: 431.673533004
# SD_H: 368.081110861
# SD_L: 136.403692261
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.82271311781e-05
#
# 1-m2
# NEURONS: 44
# LENGTH: 961.231482574
# HEIGHT: 992.160255594
# SD_H: 167.710573587
# SD_L: 127.453423752
# H_skewness: -4.935814232303147e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.63806398496e-05
#
# 2-m1
# NEURONS: 119
# LENGTH: 1457.32765967
# HEIGHT: 445.795357501
# SD_H: 335.40612529
# SD_L: 94.5655736157
# H_skewness: -2.9618864671035707e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.98560979286e-05
#
# 2-m2
# NEURONS: 57
# LENGTH: 976.6459224
# HEIGHT: 686.648843731
# SD_H: 59.8607319998
# SD_L: 83.0817607191
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 9.12047120643e-05
#
#
#
# =================================================
# 10x position_EMXCKO5-column-2-slice-2.xlsx
# 22
# 1-m1
# NEURONS: 104
# LENGTH: 1622.67792962
# HEIGHT: 401.617434412
# SD_H: 372.300588542
# SD_L: 134.786671787
# H_skewness: 2.1657095311484649e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.49930544324e-05
#
# 1-m2
# NEURONS: 20
# LENGTH: 870.919852533
# HEIGHT: 470.89634826
# SD_H: 22.5105508982
# SD_L: 64.3509111573
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 9.98818602716e-05
#
# 2-m1
# NEURONS: 140
# LENGTH: 1569.2771137
# HEIGHT: 458.448559143
# SD_H: 450.348622488
# SD_L: 153.533920202
# H_skewness: 2.447174033389614e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.46477968752e-05
#
# 2-m2
# NEURONS: 38
# LENGTH: 737.280160524
# HEIGHT: 526.947968894
# SD_H: 29.0835712941
# SD_L: 1.27838628964
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00739385975688
#
#
#
# =================================================
# 10x position_EMXCKO5-column-2-slice-3.xlsx
# 26
# 1-m1
# NEURONS: 102
# LENGTH: 1213.14015612
# HEIGHT: 534.655834658
# SD_H: 378.254783242
# SD_L: 80.2572086263
# H_skewness: -2.7533842692838324e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.05673565084e-05
#
# 1-m2
# NEURONS: 19
# LENGTH: 627.20748004
# HEIGHT: 646.008615227
# SD_H: 90.9732371157
# SD_L: 165.63506063
# H_skewness: -4.638637687051524e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.718527664e-06
#
# 2-m1
# NEURONS: 92
# LENGTH: 1227.92357482
# HEIGHT: 414.342375277
# SD_H: 383.427350038
# SD_L: 70.1517502761
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.09369305223e-05
#
# 2-m2
# NEURONS: 10
# LENGTH: 355.48656306
# HEIGHT: 208.692443041
# SD_H: 68.576655476
# SD_L: 48.8354583249
# H_skewness: -3.6097842157399147e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.82782753422e-05
#
#
#
# =================================================
# 10x position_WT1-N5-column-1-slice-1.xlsx
# 29
# M1
# NEURONS: 170
# LENGTH: 1337.96800039
# HEIGHT: 655.349848278
# SD_H: 177.605332934
# SD_L: 134.850339771
# H_skewness: 4.98716088096248e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.89549819927e-05
#
# M2
# NEURONS: 125
# LENGTH: 800.186992672
# HEIGHT: 654.750977605
# SD_H: 186.605578592
# SD_L: 78.0391175013
# H_skewness: -2.8665284542617127e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 4.71080550943e-05
#
#
#
# =================================================
# 10x position_WT1-N5-column-2-slice-1.xlsx
# 25
# M2
# NEURONS: 159
# LENGTH: 1061.15563515
# HEIGHT: 866.210566258
# SD_H: 214.978534185
# SD_L: 214.530357549
# H_skewness: 1.8747563517449873e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.19479212547e-05
#
# M1
# NEURONS: 177
# LENGTH: 1047.12689794
# HEIGHT: 633.903762586
# SD_H: 360.718945768
# SD_L: 188.423099008
# H_skewness: -2.3810829049999247e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.65786931694e-05
#
#
#
# =================================================
# 10x position_WT1-N5-column-2-slice-2.xlsx
# 40
# 1-m1
# NEURONS: 230
# LENGTH: 1377.82177277
# HEIGHT: 682.185099532
# SD_H: 456.902955992
# SD_L: 172.429073634
# H_skewness: -1.5622416402136654e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.16159173581e-05
#
# 1-m2
# NEURONS: 80
# LENGTH: 674.801461816
# HEIGHT: 776.431357836
# SD_H: 17.3282904494
# SD_L: 135.244389426
# H_skewness: -4.894305207913071e-15
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000135823573006
#
# 2-m1
# NEURONS: 304
# LENGTH: 1275.51959498
# HEIGHT: 665.723185544
# SD_H: 448.511291016
# SD_L: 269.931951193
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 9.99093306287e-06
#
# 2-m2
# NEURONS: 114
# LENGTH: 871.937561402
# HEIGHT: 617.363321384
# SD_H: 332.560945095
# SD_L: 81.7552337989
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.66831548592e-05
#
#
#
# =================================================
# 10x position_WT1-N5-column-2-slice-3.xlsx
# 39
# 1-m1
# NEURONS: 303
# LENGTH: 1575.86985351
# HEIGHT: 664.271829233
# SD_H: 476.827088528
# SD_L: 342.090622039
# H_skewness: -2.0617149149750657e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.58046880163e-06
#
# 1-m2
# NEURONS: 142
# LENGTH: 1086.68844981
# HEIGHT: 727.979054937
# SD_H: 344.464401659
# SD_L: 191.754088338
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 8.77313656957e-06
#
# 2-m1
# NEURONS: 302
# LENGTH: 1462.62830916
# HEIGHT: 721.585189406
# SD_H: 434.144597452
# SD_L: 67.3668506462
# H_skewness: 1.8210292003538794e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 4.21387667996e-05
#
# 2-m2
# NEURONS: 90
# LENGTH: 770.992103338
# HEIGHT: 848.387766313
# SD_H: 253.95976402
# SD_L: 1.14113603522
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00126734746158
#
#
#
# =================================================
# 10x position_WT2-N3-column-2-slice-1.xlsx
# 34
# 1-m1
# NEURONS: 246
# LENGTH: 1331.56382376
# HEIGHT: 649.759155129
# SD_H: 429.847153106
# SD_L: 164.613845551
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.62740597573e-05
#
# 1-m2
# NEURONS: 58
# LENGTH: 766.55442836
# HEIGHT: 672.21624726
# SD_H: 181.350637727
# SD_L: 109.600974844
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.36595283561e-05
#
# 2-m1
# NEURONS: 247
# LENGTH: 1298.37834216
# HEIGHT: 708.116375155
# SD_H: 424.211818432
# SD_L: 236.512655448
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.1523940838e-05
#
# 2-m2
# NEURONS: 79
# LENGTH: 999.282860175
# HEIGHT: 1038.7761843
# SD_H: 21.6777989146
# SD_L: 67.633468807
# H_skewness: 3.928323994496461e-15
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000252226933703
#
#
#
# =================================================
# 10x position_WT2-N3-column-2-slice-2.xlsx
# 29
# 1-m1
# NEURONS: 260
# LENGTH: 1496.13126658
# HEIGHT: 650.744096192
# SD_H: 412.129622148
# SD_L: 320.433578697
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.08049716236e-05
#
# 1-m2
# NEURONS: 115
# LENGTH: 969.328564398
# HEIGHT: 709.39282444
# SD_H: 231.691328052
# SD_L: 177.979476253
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.53052444623e-05
#
# 2-m1
# NEURONS: 262
# LENGTH: 1489.75673378
# HEIGHT: 625.865782287
# SD_H: 376.559432245
# SD_L: 195.677442037
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.95141272242e-05
#
# 2-m2
# NEURONS: 128
# LENGTH: 1005.43884452
# HEIGHT: 768.465115646
# SD_H: 410.269892766
# SD_L: 169.107818883
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.01250870882e-05
#
#
#
# =================================================
# 10x position_WT3-N3-column-1-slice-1.xlsx
# 35
# 1-m1
# NEURONS: 238
# LENGTH: 1320.78602724
# HEIGHT: 721.754487588
# SD_H: 326.917785961
# SD_L: 148.58467145
# H_skewness: -2.1324284596267528e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.22800667198e-05
#
# 1-m2
# NEURONS: 175
# LENGTH: 1097.06359182
# HEIGHT: 953.910038567
# SD_H: 373.099232863
# SD_L: 34.4377970643
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 6.19341836284e-05
#
# 2-m1
# NEURONS: 280
# LENGTH: 1526.68838737
# HEIGHT: 712.001927542
# SD_H: 443.322694517
# SD_L: 282.642160313
# H_skewness: -2.565378668230371e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.01613921149e-05
#
# 2-m2
# NEURONS: 98
# LENGTH: 1031.65093426
# HEIGHT: 802.968078657
# SD_H: 226.804148619
# SD_L: 54.2660539027
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.62075323068e-05
#
#
#
# =================================================
# 10x position_WT3-N3-column-2-slice-1.xlsx
# 37
# 1-m1
# NEURONS: 280
# LENGTH: 1552.23408829
# HEIGHT: 683.492112823
# SD_H: 508.069442061
# SD_L: 331.93676784
# H_skewness: -1.7042847066786315e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.14164080385e-06
#
# 1-m2
# NEURONS: 92
# LENGTH: 958.21124706
# HEIGHT: 738.481894959
# SD_H: 262.497379091
# SD_L: 71.9349364733
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.09575928522e-05
#
# 2-m1
# NEURONS: 267
# LENGTH: 1472.99014088
# HEIGHT: 815.997812171
# SD_H: 471.91589804
# SD_L: 346.808735015
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 7.01738062215e-06
#
# 2-m2
# NEURONS: 184
# LENGTH: 1096.0480751
# HEIGHT: 898.841717035
# SD_H: 15.7089007052
# SD_L: 141.846077685
# H_skewness: -5.45488685590686e-15
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00035520012079
#
#
#
# =================================================
# 10x position_WT3-N3-column-2-slice-2.xlsx
# 40
# 1-m1
# NEURONS: 187
# LENGTH: 991.977898096
# HEIGHT: 504.202049052
# SD_H: 364.718704248
# SD_L: 7.18814422982
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000283809499604
#
# 1-m2
# NEURONS: 73
# LENGTH: 798.425337385
# HEIGHT: 502.417483205
# SD_H: 201.14656445
# SD_L: 40.3733439403
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.57664354419e-05
#
# 2-m1
# NEURONS: 226
# LENGTH: 1075.38610298
# HEIGHT: 703.742497812
# SD_H: 373.193276859
# SD_L: 63.3357894672
# H_skewness: -2.8669404947430116e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 3.80439480443e-05
#
# 2-m2
# NEURONS: 78
# LENGTH: 887.092722588
# HEIGHT: 686.968710677
# SD_H: 96.189512947
# SD_L: 118.84398639
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.71487480021e-05
#
#
#
# =================================================
# 10x position_WT4-N5-column-2-slice-1.xlsx
# 29
# 1-m1
# NEURONS: 194
# LENGTH: 1539.21910986
# HEIGHT: 696.276448242
# SD_H: 392.73125911
# SD_L: 302.259466827
# H_skewness: -3.0749900576232806e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 8.96909206198e-06
#
# 1-m2
# NEURONS: 111
# LENGTH: 1077.08000463
# HEIGHT: 744.022959989
# SD_H: 90.7217507166
# SD_L: 50.7130722285
# H_skewness: -5.45687392440109e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000132407860731
#
# 2-m1
# NEURONS: 206
# LENGTH: 1245.28207385
# HEIGHT: 643.656620841
# SD_H: 384.253692748
# SD_L: 120.274922232
# H_skewness: 2.6264308031310106e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.4462239818e-05
#
# 2-m2
# NEURONS: 113
# LENGTH: 877.630940757
# HEIGHT: 813.421102871
# SD_H: 341.663735967
# SD_L: 200.727299703
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 9.04264017101e-06
#
#
#
# =================================================
# 10x position_WT5-N3-column-2-slice-1.xlsx
# 33
# 1-m1
# NEURONS: 241
# LENGTH: 1358.51043327
# HEIGHT: 626.180541865
# SD_H: 262.328971884
# SD_L: 218.644595855
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 2.02646090493e-05
#
# 1-m2
# NEURONS: 114
# LENGTH: 1027.31697696
# HEIGHT: 558.995606111
# SD_H: 221.022758913
# SD_L: 47.6156017555
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 5.22425984972e-05
#
# 2-m1
# NEURONS: 159
# LENGTH: 1160.69648519
# HEIGHT: 551.714821295
# SD_H: 274.699651733
# SD_L: 172.37210829
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.61948978765e-05
#
# 2-m2
# NEURONS: 86
# LENGTH: 855.770713814
# HEIGHT: 652.230277062
# SD_H: 306.868516862
# SD_L: 11.3916731707
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000118649193961
#
#
#
# =================================================
# 10x position_WT5-N3-column-2-slice-2.xlsx
# 45
# 1-m1
# NEURONS: 261
# LENGTH: 1291.14442466
# HEIGHT: 913.579246685
# SD_H: 516.157549224
# SD_L: 277.741666914
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 6.43909457517e-06
#
# 1-m2
# NEURONS: 92
# LENGTH: 1045.1670553
# HEIGHT: 812.406168528
# SD_H: 180.537431703
# SD_L: 103.732387689
# H_skewness: -4.748097243061289e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.73745598233e-05
#
# 2-m1
# NEURONS: 233
# LENGTH: 1272.05240981
# HEIGHT: 623.980597989
# SD_H: 411.711687561
# SD_L: 185.60474672
# H_skewness: -2.135209658619445e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.07840343929e-05
#
# 2-m2
# NEURONS: 92
# LENGTH: 616.356305399
# HEIGHT: 625.94962797
# SD_H: 177.327682261
# SD_L: 11.8893025128
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000154334326145
#
#
#
# =================================================
# 10x position_WT5-N3-column-2-slice-3.xlsx
# 33
# 1-m1
# NEURONS: 248
# LENGTH: 1151.67539167
# HEIGHT: 599.69618489
# SD_H: 262.567224332
# SD_L: 9.79218737947
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000465197791286
#
# 1-m2
# NEURONS: 70
# LENGTH: 744.986791782
# HEIGHT: 628.334298718
# SD_H: 85.5388908562
# SD_L: 38.7154368697
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.00010194277534
#
# 2-m1
# NEURONS: 184
# LENGTH: 1168.42121079
# HEIGHT: 604.96530253
# SD_H: 227.057538763
# SD_L: 47.4425716209
# H_skewness: -1.5911911256458554e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 8.23796356767e-05
#
# 2-m2
# NEURONS: 59
# LENGTH: 754.653381996
# HEIGHT: 565.936057699
# SD_H: 101.146891273
# SD_L: 31.4823121662
# H_skewness: 1.6875000098400405e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 8.93591529008e-05
#
#
#
# =================================================
# 10x position_WT6-N5-column-2-slice-1.xlsx
# 32
# 1-m1
# NEURONS: 270
# LENGTH: 1691.74989158
# HEIGHT: 615.740270044
# SD_H: 464.879794701
# SD_L: 309.695783294
# H_skewness: -1.483194481122788e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 9.32734315063e-06
#
# 1-m2
# NEURONS: 92
# LENGTH: 1107.0154079
# HEIGHT: 619.040761185
# SD_H: 384.383693569
# SD_L: 101.876757747
# H_skewness: 0.0
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.16847092426e-05
#
# 2-m1
# NEURONS: 181
# LENGTH: 1113.82117918
# HEIGHT: 648.799358855
# SD_H: 251.624448271
# SD_L: 181.311829791
# H_skewness: 1.753730592156741e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 1.97319384344e-05
#
# 2-m2
# NEURONS: 57
# LENGTH: 786.040234762
# HEIGHT: 543.310840471
# SD_H: 109.349691135
# SD_L: 17.4420560633
# H_skewness: -1.7806864611573745e-16
# DENSITY NOT ADJUSTED TO BRAIN SLICE THICKNESS: 0.000148637971656
#
#
# ╒═══════════════════════════════════════╤════════╤═══════════╤═════════════╤══════════╤══════════╤═══════════╤═══════════╤════════════╕
# │ Filename                              │ Area   │   Neurons │     Density │        H │        L │      SD_H │      SD_L │ Genotype   │
# ╞═══════════════════════════════════════╪════════╪═══════════╪═════════════╪══════════╪══════════╪═══════════╪═══════════╪════════════╡
# │ EMXCKO1-slice-3.xlsx                  │ M1     │       192 │ 1.89607e-05 │ 1270.75  │  514.578 │ 339.93    │ 197.545   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-3.xlsx                  │ M2     │        62 │ 6.11474e-05 │  858.129 │  770.25  │  50.0472  │ 134.352   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-3.xlsx                  │ M1     │       196 │ 2.29736e-05 │ 1350.14  │  557.789 │ 441.882   │ 128.035   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-3.xlsx                  │ M2     │        48 │ 7.21712e-05 │  760.262 │  644.799 │ 223.091   │  19.7698  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-5.xlsx                  │ M1     │       122 │ 2.87633e-05 │ 1301.19  │  433.952 │ 157.905   │ 185.874   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-5.xlsx                  │ M2     │        34 │ 1.25021e-05 │  669.513 │  340.893 │ 130.858   │ 143.81    │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-5.xlsx                  │ M1     │        96 │ 1.84325e-05 │ 1342.22  │  369.998 │ 358.12    │ 100.635   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO1-slice-5.xlsx                  │ M2     │        39 │ 1.03779e-05 │  916.128 │  634.604 │ 192.812   │ 134.87    │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-3.xlsx                  │ M1     │       159 │ 4.42622e-05 │ 1053.48  │  493.595 │ 214.175   │ 102.67    │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-3.xlsx                  │ M2     │        52 │ 0.000155472 │ 1006.2   │  777.367 │ 223.811   │   9.14777 │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-3.xlsx                  │ M1     │       140 │ 2.70886e-05 │  925.371 │  444.344 │ 287.755   │ 109.942   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-3.xlsx                  │ M2     │        79 │ 3.85971e-05 │ 1012.03  │  912.065 │ 306.957   │  40.8171  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-4.xlsx                  │ M1     │       148 │ 1.48062e-05 │ 1399.52  │  382.739 │ 310.336   │ 176.77    │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-4.xlsx                  │ M2     │        42 │ 2.66867e-05 │  827.769 │  409.804 │ 200.916   │  42.9895  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-4.xlsx                  │ M1     │       136 │ 1.181e-05   │ 1409.65  │  407.531 │ 343.485   │ 183.993   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-4.xlsx                  │ M2     │        57 │ 1.85067e-05 │  508.116 │  503.741 │ 220.47    │  76.6686  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-5.xlsx                  │ M1     │        89 │ 2.19599e-05 │ 1370     │  425.267 │ 355.728   │  75.5527  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-5.xlsx                  │ M2     │        29 │ 6.11219e-06 │  758.348 │  440.511 │ 163.192   │ 192.802   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-5.xlsx                  │ M1     │       106 │ 3.41872e-05 │ 1357.47  │  364.024 │ 290.945   │  70.671   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO2-slice-5.xlsx                  │ M2     │        33 │ 4.8493e-05  │  832.478 │  447.172 │ 265.458   │  16.9999  │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCKO3-slice-3-stitch2.xlsx          │ M1     │       151 │ 1.01785e-05 │ 1443.83  │  557.621 │ 427.559   │ 230.095   │ CKO        │
# ├───────────────────────────────────────┼────────┼───────────┼─────────────┼──────────┼──────────┼───────────┼───────────┼────────────┤
# │ EMXCK